# %% [markdown]
# ### Anotações

# %%
from IPython.display import Image
img = "D:/TFS/c-sharp-priv/Web-api-aspNetCore-essencial/Anotacoes/img/"

# %%
# Brincando c python. Criei esta função em python para abrir qualquer imagem que esteja dentro da pasta padrão img,
# acima declarada.
def showImg(name, w, h):
    v= Image(filename = img+name, width=w, height=h)
    return v

#Exemplo de chamada showImg("RESTFull-verbs.jpg", 500, 500)

# %% [markdown]
# Criando uma aplicação RESTFull, que vai aderir aos Verbs Get, Post, Put e Delete e o header, body, location e media-type.
#
# Primeiramente precisamos decidir o que nossa Web Api vai expor de serviços, por exemplo:
#
# Todos os livros cadastrados
# Um livro cadastrados
# Todos os livros de um ator
#
# Após definidos mapeamos os recursos para as URIs
#
# http://api/projeto/livros
#
# http://api/projeto/livros/1
#
# http://api/projeto/autor/1/livros

# %%
showImg("RESTFull-verbs.jpg", 500, 500)
